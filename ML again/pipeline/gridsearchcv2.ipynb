# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV
from sklearn.datasets import load_iris
from sklearn.metrics import mean_squared_error
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline

# %%
X,y = load_iris(return_X_y=True)

# %%
pipe =Pipeline([
    ('scaling',StandardScaler()),
    ('logo',KNeighborsRegressor())
])

# %%
pipe.get_params()
# Out:
# {'memory': None,
#  'steps': [('scaling', StandardScaler()), ('logo', KNeighborsRegressor())],
#  'verbose': False,
#  'scaling': StandardScaler(),
#  'logo': KNeighborsRegressor(),
#  'scaling__copy': True,
#  'scaling__with_mean': True,
#  'scaling__with_std': True,
#  'logo__algorithm': 'auto',
#  'logo__leaf_size': 30,
#  'logo__metric': 'minkowski',
#  'logo__metric_params': None,
#  'logo__n_jobs': None,
#  'logo__n_neighbors': 5,
#  'logo__p': 2,
#  'logo__weights': 'uniform'}

# %%
model = GridSearchCV(
    estimator=pipe,
    param_grid={'logo__n_neighbors':[1,2,3,4,5,6,7,8,9]},
    cv= 5  # CCV means Cross Validations it test data 5 times
)

# %%
model.fit(X,y)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaling', StandardScaler()),
#                                        ('logo', KNeighborsRegressor())]),
#              param_grid={'logo__n_neighbors': [1, 2, 3, 4, 5, 6, 7, 8, 9]})

# %%
import pandas as pd
pd.DataFrame(model.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.003000      0.002322         0.003301        0.002085
# 1       0.005273      0.002741         0.001192        0.000740
# 2       0.001226      0.001199         0.001864        0.002855
# 3       0.004790      0.003646         0.000845        0.000975
# 4       0.003284      0.002083         0.001520        0.001222
# 5       0.001503      0.001644         0.002114        0.002294
# 6       0.002498      0.003397         0.002174        0.002331
# 7       0.004055      0.002747         0.000962        0.000856
# 8       0.002138      0.001490         0.001290        0.001133
#
#   param_logo__n_neighbors                    params  split0_test_score  \
# 0                       1  {'logo__n_neighbors': 1}                1.0
# 1                       2  {'logo__n_neighbors': 2}                1.0
# 2                       3  {'logo__n_neighbors': 3}                1.0
# 3                       4  {'logo__n_neighbors': 4}                1.0
# 4                       5  {'logo__n_neighbors': 5}                1.0
# 5                       6  {'logo__n_neighbors': 6}                1.0
# 6                       7  {'logo__n_neighbors': 7}                1.0
# 7                       8  {'logo__n_neighbors': 8}                1.0
# 8                       9  {'logo__n_neighbors': 9}                1.0
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.850000                0.0           0.700000                0.0
# 1           0.925000                0.0           0.662500                0.0
# 2           0.950000                0.0           0.650000                0.0
# 3           0.943750                0.0           0.662500                0.0
# 4           0.934000                0.0           0.676000                0.0
# 5           0.929167                0.0           0.766667                0.0
# 6           0.917347                0.0           0.761224                0.0
# 7           0.887500                0.0           0.767969                0.0
# 8           0.866667                0.0           0.744444                0.0
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.510000        0.427083                9
# 1         0.517500        0.437150                8
# 2         0.520000        0.441135                7
# 3         0.521250        0.440695                6
# 4         0.522000        0.439753                5
# 5         0.539167        0.446682                1
# 6         0.535714        0.444081                2
# 7         0.531094        0.439802                3
# 8         0.522222        0.433988                4
