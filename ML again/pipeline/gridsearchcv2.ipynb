# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV
from sklearn.datasets import load_iris
from sklearn.metrics import mean_squared_error
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
import seaborn as sns

# %%
df = sns.load_dataset("mpg")
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
df.drop(['horsepower'],axis=True,inplace=True)

# %%
X = df.iloc[:,:-2]
y = df.iloc[:,-1]

# %%
X.head()
# Out:
#     mpg  cylinders  displacement  weight  acceleration  model_year
# 0  18.0          8         307.0    3504          12.0          70
# 1  15.0          8         350.0    3693          11.5          70
# 2  18.0          8         318.0    3436          11.0          70
# 3  16.0          8         304.0    3433          12.0          70
# 4  17.0          8         302.0    3449          10.5          70

# %%
y.head()
# Out:
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# 2           plymouth satellite
# 3                amc rebel sst
# 4                  ford torino
# Name: name, dtype: object

# %%
pipe = Pipeline([
                  ('scaling',StandardScaler()),
                ('Logo',KNeighborsRegressor())
])

# %%
pipe.get_params()
# Out:
# {'memory': None,
#  'steps': [('scaling', StandardScaler()), ('Logo', KNeighborsRegressor())],
#  'verbose': False,
#  'scaling': StandardScaler(),
#  'Logo': KNeighborsRegressor(),
#  'scaling__copy': True,
#  'scaling__with_mean': True,
#  'scaling__with_std': True,
#  'Logo__algorithm': 'auto',
#  'Logo__leaf_size': 30,
#  'Logo__metric': 'minkowski',
#  'Logo__metric_params': None,
#  'Logo__n_jobs': None,
#  'Logo__n_neighbors': 5,
#  'Logo__p': 2,
#  'Logo__weights': 'uniform'}

# %%
model = GridSearchCV(
    estimator=pipe,
    param_grid={'Logo__n_neighbors':[1,2,3,4,5,6]},
    cv =5
)

# %%
model.fit(X,y)
# Out:
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py", line 430, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py", line 723, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 692, in score
#     y_pred = self.predict(X)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_regression.py", line 248, in predict
#     y_pred = np.mean(_y[neigh_ind], axis=1)
#   File "<__array_function__ internals>", line 180, in mean
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py", line 3432, in mean
#     return _methods._mean(a, axis=axis, dtype=dtype,
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py", line 182, in _mean
#     ret = um.true_divide(
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
#   warnings.warn(
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py", line 430, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py", line 723, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 692, in score
#     y_pred = self.predict(X)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_regression.py", line 248, in predict
#     y_pred = np.mean(_y[neigh_ind], axis=1)
#   File "<__array_function__ internals>", line 180, in mean
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py", line 3432, in mean
#     return _methods._mean(a, axis=axis, dtype=dtype,
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py", line 182, in _mean
#     ret = um.true_divide(
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
#   warnings.warn(
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py", line 430, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py", line 723, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 692, in score
#     y_pred = self.predict(X)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_regression.py", line 248, in predict
#     y_pred = np.mean(_y[neigh_ind], axis=1)
#   File "<__array_function__ internals>", line 180, in mean
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py", line 3432, in mean
#     return _methods._mean(a, axis=axis, dtype=dtype,
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py", line 182, in _mean
#     ret = um.true_divide(
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
#   warnings.warn(
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py", line 430, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py", line 723, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 692, in score
#     y_pred = self.predict(X)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_regression.py", line 248, in predict
#     y_pred = np.mean(_y[neigh_ind], axis=1)
#   File "<__array_function__ internals>", line 180, in mean
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py", line 3432, in mean
#     return _methods._mean(a, axis=axis, dtype=dtype,
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py", line 182, in _mean
#     ret = um.true_divide(
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
#   warnings.warn(
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py", line 430, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py", line 723, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 692, in score
#     y_pred = self.predict(X)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_regression.py", line 248, in predict
#     y_pred = np.mean(_y[neigh_ind], axis=1)
#   File "<__array_function__ internals>", line 180, in mean
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py", line 3432, in mean
#     return _methods._mean(a, axis=axis, dtype=dtype,
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py", line 182, in _mean
#     ret = um.true_divide(
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
#   warnings.warn(
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py", line 430, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py", line 723, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 692, in score
#     y_pred = self.predict(X)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_regression.py", line 248, in predict
#     y_pred = np.mean(_y[neigh_ind], axis=1)
#   File "<__array_function__ internals>", line 180, in mean
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py", line 3432, in mean
#     return _methods._mean(a, axis=axis, dtype=dtype,
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py", line 182, in _mean
#     ret = um.true_divide(
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
#   warnings.warn(
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py", line 430, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py", line 723, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 692, in score
#     y_pred = self.predict(X)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_regression.py", line 248, in predict
#     y_pred = np.mean(_y[neigh_ind], axis=1)
#   File "<__array_function__ internals>", line 180, in mean
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py", line 3432, in mean
#     return _methods._mean(a, axis=axis, dtype=dtype,
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py", line 182, in _mean
#     ret = um.true_divide(
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
#   warnings.warn(
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py", line 430, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py", line 723, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 692, in score
#     y_pred = self.predict(X)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_regression.py", line 248, in predict
#     y_pred = np.mean(_y[neigh_ind], axis=1)
#   File "<__array_function__ internals>", line 180, in mean
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py", line 3432, in mean
#     return _methods._mean(a, axis=axis, dtype=dtype,
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py", line 182, in _mean
#     ret = um.true_divide(
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
#   warnings.warn(
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py", line 430, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py", line 723, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 692, in score
#     y_pred = self.predict(X)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_regression.py", line 248, in predict
#     y_pred = np.mean(_y[neigh_ind], axis=1)
#   File "<__array_function__ internals>", line 180, in mean
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py", line 3432, in mean
#     return _methods._mean(a, axis=axis, dtype=dtype,
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py", line 182, in _mean
#     ret = um.true_divide(
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
#   warnings.warn(
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py", line 430, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py", line 723, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 692, in score
#     y_pred = self.predict(X)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_regression.py", line 248, in predict
#     y_pred = np.mean(_y[neigh_ind], axis=1)
#   File "<__array_function__ internals>", line 180, in mean
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py", line 3432, in mean
#     return _methods._mean(a, axis=axis, dtype=dtype,
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py", line 182, in _mean
#     ret = um.true_divide(
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
#   warnings.warn(
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py", line 430, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py", line 723, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 692, in score
#     y_pred = self.predict(X)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_regression.py", line 248, in predict
#     y_pred = np.mean(_y[neigh_ind], axis=1)
#   File "<__array_function__ internals>", line 180, in mean
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py", line 3432, in mean
#     return _methods._mean(a, axis=axis, dtype=dtype,
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py", line 182, in _mean
#     ret = um.true_divide(
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
#   warnings.warn(
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py", line 430, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py", line 723, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 692, in score
#     y_pred = self.predict(X)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_regression.py", line 248, in predict
#     y_pred = np.mean(_y[neigh_ind], axis=1)
#   File "<__array_function__ internals>", line 180, in mean
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py", line 3432, in mean
#     return _methods._mean(a, axis=axis, dtype=dtype,
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py", line 182, in _mean
#     ret = um.true_divide(
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
#   warnings.warn(
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py", line 430, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py", line 723, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 692, in score
#     y_pred = self.predict(X)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_regression.py", line 248, in predict
#     y_pred = np.mean(_y[neigh_ind], axis=1)
#   File "<__array_function__ internals>", line 180, in mean
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py", line 3432, in mean
#     return _methods._mean(a, axis=axis, dtype=dtype,
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py", line 182, in _mean
#     ret = um.true_divide(
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
#   warnings.warn(
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py", line 430, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py", line 723, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 692, in score
#     y_pred = self.predict(X)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_regression.py", line 248, in predict
#     y_pred = np.mean(_y[neigh_ind], axis=1)
#   File "<__array_function__ internals>", line 180, in mean
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py", line 3432, in mean
#     return _methods._mean(a, axis=axis, dtype=dtype,
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py", line 182, in _mean
#     ret = um.true_divide(
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
#   warnings.warn(
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py", line 430, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py", line 723, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 692, in score
#     y_pred = self.predict(X)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_regression.py", line 248, in predict
#     y_pred = np.mean(_y[neigh_ind], axis=1)
#   File "<__array_function__ internals>", line 180, in mean
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py", line 3432, in mean
#     return _methods._mean(a, axis=axis, dtype=dtype,
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py", line 182, in _mean
#     ret = um.true_divide(
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
#   warnings.warn(
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py", line 430, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py", line 723, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 692, in score
#     y_pred = self.predict(X)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_regression.py", line 248, in predict
#     y_pred = np.mean(_y[neigh_ind], axis=1)
#   File "<__array_function__ internals>", line 180, in mean
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py", line 3432, in mean
#     return _methods._mean(a, axis=axis, dtype=dtype,
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py", line 182, in _mean
#     ret = um.true_divide(
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
#   warnings.warn(
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py", line 430, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py", line 723, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 692, in score
#     y_pred = self.predict(X)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_regression.py", line 248, in predict
#     y_pred = np.mean(_y[neigh_ind], axis=1)
#   File "<__array_function__ internals>", line 180, in mean
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py", line 3432, in mean
#     return _methods._mean(a, axis=axis, dtype=dtype,
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py", line 182, in _mean
#     ret = um.true_divide(
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
#   warnings.warn(
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py", line 430, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py", line 723, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 692, in score
#     y_pred = self.predict(X)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_regression.py", line 248, in predict
#     y_pred = np.mean(_y[neigh_ind], axis=1)
#   File "<__array_function__ internals>", line 180, in mean
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py", line 3432, in mean
#     return _methods._mean(a, axis=axis, dtype=dtype,
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py", line 182, in _mean
#     ret = um.true_divide(
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
#   warnings.warn(
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py", line 430, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py", line 723, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 692, in score
#     y_pred = self.predict(X)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_regression.py", line 248, in predict
#     y_pred = np.mean(_y[neigh_ind], axis=1)
#   File "<__array_function__ internals>", line 180, in mean
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py", line 3432, in mean
#     return _methods._mean(a, axis=axis, dtype=dtype,
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py", line 182, in _mean
#     ret = um.true_divide(
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
#   warnings.warn(
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py", line 430, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py", line 723, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 692, in score
#     y_pred = self.predict(X)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_regression.py", line 248, in predict
#     y_pred = np.mean(_y[neigh_ind], axis=1)
#   File "<__array_function__ internals>", line 180, in mean
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py", line 3432, in mean
#     return _methods._mean(a, axis=axis, dtype=dtype,
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py", line 182, in _mean
#     ret = um.true_divide(
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
#   warnings.warn(
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py", line 430, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py", line 723, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 692, in score
#     y_pred = self.predict(X)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_regression.py", line 248, in predict
#     y_pred = np.mean(_y[neigh_ind], axis=1)
#   File "<__array_function__ internals>", line 180, in mean
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py", line 3432, in mean
#     return _methods._mean(a, axis=axis, dtype=dtype,
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py", line 182, in _mean
#     ret = um.true_divide(
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
#   warnings.warn(
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py", line 430, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py", line 723, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 692, in score
#     y_pred = self.predict(X)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_regression.py", line 248, in predict
#     y_pred = np.mean(_y[neigh_ind], axis=1)
#   File "<__array_function__ internals>", line 180, in mean
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py", line 3432, in mean
#     return _methods._mean(a, axis=axis, dtype=dtype,
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py", line 182, in _mean
#     ret = um.true_divide(
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
#   warnings.warn(
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py", line 430, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py", line 723, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 692, in score
#     y_pred = self.predict(X)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_regression.py", line 248, in predict
#     y_pred = np.mean(_y[neigh_ind], axis=1)
#   File "<__array_function__ internals>", line 180, in mean
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py", line 3432, in mean
#     return _methods._mean(a, axis=axis, dtype=dtype,
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py", line 182, in _mean
#     ret = um.true_divide(
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
#   warnings.warn(
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py", line 430, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py", line 723, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 692, in score
#     y_pred = self.predict(X)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_regression.py", line 248, in predict
#     y_pred = np.mean(_y[neigh_ind], axis=1)
#   File "<__array_function__ internals>", line 180, in mean
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py", line 3432, in mean
#     return _methods._mean(a, axis=axis, dtype=dtype,
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py", line 182, in _mean
#     ret = um.true_divide(
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
#   warnings.warn(
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py", line 430, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py", line 723, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 692, in score
#     y_pred = self.predict(X)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_regression.py", line 248, in predict
#     y_pred = np.mean(_y[neigh_ind], axis=1)
#   File "<__array_function__ internals>", line 180, in mean
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py", line 3432, in mean
#     return _methods._mean(a, axis=axis, dtype=dtype,
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py", line 182, in _mean
#     ret = um.true_divide(
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
#   warnings.warn(
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py", line 430, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py", line 723, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 692, in score
#     y_pred = self.predict(X)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_regression.py", line 248, in predict
#     y_pred = np.mean(_y[neigh_ind], axis=1)
#   File "<__array_function__ internals>", line 180, in mean
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py", line 3432, in mean
#     return _methods._mean(a, axis=axis, dtype=dtype,
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py", line 182, in _mean
#     ret = um.true_divide(
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
#   warnings.warn(
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py", line 430, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py", line 723, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 692, in score
#     y_pred = self.predict(X)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_regression.py", line 248, in predict
#     y_pred = np.mean(_y[neigh_ind], axis=1)
#   File "<__array_function__ internals>", line 180, in mean
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py", line 3432, in mean
#     return _methods._mean(a, axis=axis, dtype=dtype,
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py", line 182, in _mean
#     ret = um.true_divide(
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
#   warnings.warn(
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py", line 430, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py", line 723, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 692, in score
#     y_pred = self.predict(X)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_regression.py", line 248, in predict
#     y_pred = np.mean(_y[neigh_ind], axis=1)
#   File "<__array_function__ internals>", line 180, in mean
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py", line 3432, in mean
#     return _methods._mean(a, axis=axis, dtype=dtype,
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py", line 182, in _mean
#     ret = um.true_divide(
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
#   warnings.warn(
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py", line 430, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py", line 723, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 692, in score
#     y_pred = self.predict(X)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_regression.py", line 248, in predict
#     y_pred = np.mean(_y[neigh_ind], axis=1)
#   File "<__array_function__ internals>", line 180, in mean
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py", line 3432, in mean
#     return _methods._mean(a, axis=axis, dtype=dtype,
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py", line 182, in _mean
#     ret = um.true_divide(
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
#   warnings.warn(
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py", line 430, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py", line 723, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 692, in score
#     y_pred = self.predict(X)
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_regression.py", line 248, in predict
#     y_pred = np.mean(_y[neigh_ind], axis=1)
#   File "<__array_function__ internals>", line 180, in mean
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py", line 3432, in mean
#     return _methods._mean(a, axis=axis, dtype=dtype,
#   File "c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py", line 182, in _mean
#     ret = um.true_divide(
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
#   warnings.warn(
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_search.py:953: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan]
#   warnings.warn(
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaling', StandardScaler()),
#                                        ('Logo', KNeighborsRegressor())]),
#              param_grid={'Logo__n_neighbors': [1, 2, 3, 4, 5, 6]})

# %%
import pandas as pd
pd.DataFrame(model.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.004946      0.003647         0.008052        0.004451
# 1       0.007264      0.005575         0.005529        0.004607
# 2       0.004200      0.004018         0.002808        0.004211
# 3       0.004898      0.003065         0.004837        0.003916
# 4       0.005164      0.005085         0.001322        0.001810
# 5       0.005680      0.005061         0.002411        0.002960
#
#   param_Logo__n_neighbors                    params  split0_test_score  \
# 0                       1  {'Logo__n_neighbors': 1}                NaN
# 1                       2  {'Logo__n_neighbors': 2}                NaN
# 2                       3  {'Logo__n_neighbors': 3}                NaN
# 3                       4  {'Logo__n_neighbors': 4}                NaN
# 4                       5  {'Logo__n_neighbors': 5}                NaN
# 5                       6  {'Logo__n_neighbors': 6}                NaN
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
# 5                NaN                NaN                NaN                NaN
#
#    mean_test_score  std_test_score  rank_test_score
# 0              NaN             NaN                1
# 1              NaN             NaN                1
# 2              NaN             NaN                1
# 3              NaN             NaN                1
# 4              NaN             NaN                1
# 5              NaN             NaN                1
