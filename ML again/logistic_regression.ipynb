# %%
import  pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df['sex'] = df['sex'].replace('Male', 1)
df['sex'] = df['sex'].replace('Female',0)

# %%
df.sample(5)
# Out:
#      total_bill   tip sex smoker   day    time  size
# 144       16.43  2.30   0     No  Thur   Lunch     2
# 183       23.17  6.50   1    Yes   Sun  Dinner     4
# 14        14.83  3.02   0     No   Sun  Dinner     2
# 187       30.46  2.00   1    Yes   Sun  Dinner     5
# 240       27.18  2.00   0    Yes   Sat  Dinner     2

# %%
# data splitting
X = df[['total_bill','tip','sex']]
y = df['smoker']

# %%
X.head()
# Out:
#    total_bill   tip sex
# 0       16.99  1.01   0
# 1       10.34  1.66   1
# 2       21.01  3.50   1
# 3       23.68  3.31   1
# 4       24.59  3.61   0

# %%
y.head()
# Out:
# 0    No
# 1    No
# 2    No
# 3    No
# 4    No
# Name: smoker, dtype: category
# Categories (2, object): ['Yes', 'No']

# %%
# machine Learning Alogrithm apply
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
model.predict([[16.99,1.01,0]])
# Out:
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['No'], dtype=object)

# %%
model.predict([[16.58,4.00,1]])
# Out:
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Yes'], dtype=object)

# %%
model.score(X,y)
# Out:
# 0.9959016393442623

# %%
plt.plot(X,y)
# Out:
# [<matplotlib.lines.Line2D at 0x21188b495d0>,
#  <matplotlib.lines.Line2D at 0x21188b493f0>,
#  <matplotlib.lines.Line2D at 0x21188b49420>]

# %%
# now check accuracy and splitt data
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=0)

# %%
X_train.shape
# Out:
# (195, 3)

# %%
X_test.shape
# Out:
# (49, 3)

# %%
model = DecisionTreeClassifier().fit(X_train,y_train)

# %%
model.score(X_test, y_test)
# Out:
# 0.5306122448979592

# %%
predicted_values = model.predict(X_test)
predicted_values
# Out:
# array(['No', 'No', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'Yes',
#        'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes',
#        'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No',
#        'Yes', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No',
#        'Yes', 'No', 'Yes', 'No', 'No', 'No', 'Yes'], dtype=object)

# %%
from sklearn.metrics import accuracy_score
score = accuracy_score(y_test,predicted_values)

# %%
score
# Out:
# 0.5306122448979592

# %%
# pip install Joblib

# %%
# how to save your model and 
# How to train your  model and run in future use
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
import joblib
model = DecisionTreeClassifier().fit(X,y)
joblib.dump(model,"name.joblib" )
# Out:
# ['name.joblib']

# %%
# Graph  Now Dot files
from sklearn import tree
model = DecisionTreeClassifier().fit(X,y)
# using Graphviz 
tree.export_graphviz(model,
                     out_file ="fooddata.dot",
                     features_names=["total_bill","tip","sex"],
                     class_names =sorted(y.unique()),
                     label = 'all',
                     rounded= True,
                     filled=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [61], line 5
#       3 model = DecisionTreeClassifier().fit(X,y)
#       4 # using Graphviz
# ----> 5 tree.export_graphviz(model,
#       6                      out_file ="fooddata.dot",
#       7                      features_names=["total_bill","tip","sex"],
#       8                      class_names =sorted(y.unique()),
#       9                      label = 'all',
#      10                      rounded= True,
#      11                      filled=True)
#
# TypeError: export_graphviz() got an unexpected keyword argument 'features_names'
