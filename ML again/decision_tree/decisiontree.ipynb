# %%
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df['sex'] = df['sex'].replace('Male', 1)
df['sex'] = df['sex'].replace('Female',0)

# %%
df.sample(5)
# Out:
#      total_bill   tip sex smoker   day    time  size
# 198       13.00  2.00   0    Yes  Thur   Lunch     2
# 229       22.12  2.88   0    Yes   Sat  Dinner     2
# 209       12.76  2.23   0    Yes   Sat  Dinner     2
# 106       20.49  4.06   1    Yes   Sat  Dinner     2
# 163       13.81  2.00   1     No   Sun  Dinner     2

# %%
# data splitting
X = df[['total_bill','tip','sex']]
y = df['smoker']

# %%
X.head()
# Out:
#    total_bill   tip sex
# 0       16.99  1.01   0
# 1       10.34  1.66   1
# 2       21.01  3.50   1
# 3       23.68  3.31   1
# 4       24.59  3.61   0

# %%
y.head()
# Out:
# 0    No
# 1    No
# 2    No
# 3    No
# 4    No
# Name: smoker, dtype: category
# Categories (2, object): ['Yes', 'No']

# %%
# machine Learning Alogrithm apply
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
model.predict([[16.99,1.01,0]])
# Out:
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['No'], dtype=object)

# %%
model.predict([[16.58,4.00,1]])
# Out:
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Yes'], dtype=object)

# %%
model.score(X,y)
# Out:
# 0.9959016393442623

# %%
plt.plot(X,y)
# Out:
# [<matplotlib.lines.Line2D at 0x20e9c42f160>,
#  <matplotlib.lines.Line2D at 0x20e9c42f100>,
#  <matplotlib.lines.Line2D at 0x20e9c42f130>]

# %% [markdown]
# # DecisionTreeClassifier

# %%
# now check accuracy and splitt data
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=0)

# %%
X_train.shape
# Out:
# (195, 3)

# %%
X_test.shape
# Out:
# (49, 3)

# %%
model = DecisionTreeClassifier().fit(X_train,y_train)

# %%
model.score(X_test, y_test)
# Out:
# 0.5306122448979592

# %%
predicted_values = model.predict(X_test)
predicted_values
# Out:
# array(['No', 'No', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'Yes',
#        'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes',
#        'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No',
#        'Yes', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No',
#        'Yes', 'No', 'Yes', 'No', 'No', 'No', 'Yes'], dtype=object)

# %%
from sklearn.metrics import accuracy_score
score = accuracy_score(y_test,predicted_values)

# %%
score
# Out:
# 0.5306122448979592

# %%
# pip install Joblib

# %%
# how to save your model and 
# How to train your  model and run in future use
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
import joblib
model = DecisionTreeClassifier().fit(X,y)
joblib.dump(model,"name.joblib" )
# Out:
# ['name.joblib']

# %%
# Graph  Now Dot files
from sklearn import tree
model = DecisionTreeClassifier()
model.fit(X,y)
# using Graphviz
# Out:
# DecisionTreeClassifier()

# %%
sklearn.tree.export_graphviz(model,
                     out_file ="fooddata.dot",
                     feature_names=["total_bill","tip","sex"],
                     class_names =sorted(y.unique()),
                     label = 'all',
                     rounded= True,
                     filled=True)

# %% [markdown]
# # Decision tree apply on dataset

# %%
boat = sns.load_dataset("iris")
boat.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
X = boat[['sepal_length','sepal_width','petal_length','petal_width']]
y = boat['species']

# %%
X.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
y.head()
# Out:
# 0    setosa
# 1    setosa
# 2    setosa
# 3    setosa
# 4    setosa
# Name: species, dtype: object

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
model.predict([[5.1,3.5,1.4,0.2]])
# Out:
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['setosa'], dtype=object)

# %%
model.predict([[4.7,3.2,1.3,0.2]])
# Out:
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['setosa'], dtype=object)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X, y,test_size=0.20,random_state=0)

# %%
model = DecisionTreeClassifier()
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
yp=model.predict(X_test)
yp
# Out:
# array(['virginica', 'versicolor', 'setosa', 'virginica', 'setosa',
#        'virginica', 'setosa', 'versicolor', 'versicolor', 'versicolor',
#        'virginica', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'setosa', 'versicolor', 'versicolor', 'setosa',
#        'setosa', 'virginica', 'versicolor', 'setosa', 'setosa',
#        'virginica', 'setosa', 'setosa', 'versicolor', 'versicolor',
#        'setosa'], dtype=object)

# %%
model.score(X_train, y_train)
# Out:
# 1.0

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %%
plt.plot(X,y)
# Out:
# [<matplotlib.lines.Line2D at 0x20e9c55fb80>,
#  <matplotlib.lines.Line2D at 0x20e9c55fb20>,
#  <matplotlib.lines.Line2D at 0x20e9c55fb50>,
#  <matplotlib.lines.Line2D at 0x20e9c55fcd0>]

# %%
# 30,70 method train test method
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.30,random_state=0)

# %%
model.score(X_test, y_test)
# Out:
# 0.35

# %%
# 40,60 method train test method
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.40,random_state=0)

# %%
model.score(X_test, y_test)
# Out:
# 0.5125

# %%
# 50,50 method train test method
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.50,random_state=0)

# %%
model.score(X_test, y_test)
# Out:
# 0.6080402010050251

# %% [markdown]
# # Savefig file in tiff or png,pdf

# %%
from sklearn.tree import plot_tree
plot_tree(model,filled=True)
plt.savefig("tiff_compresssed.tiff",dpi =600,format = 'tiff',
            facecolor = 'white',edgecolor = None)
pil_kwargs = {"compression":"tiff_lzw"}
plt.show()

# %%
from sklearn.tree import plot_tree
plot_tree(model,filled=True)
plt.savefig("tiff_compresssed.tiff",dpi =600,format = 'pdf',
            facecolor = 'white',edgecolor = None)
pil_kwargs = {"compression":"tiff_lzw"}
plt.show()

# %%
from sklearn.tree import plot_tree
plot_tree(model,filled=True)
plt.savefig("tiff_compresssed.tiff",dpi =600,format = 'png',
            facecolor = 'white',edgecolor = None)
pil_kwargs = {"compression":"tiff_lzw"}
plt.show()

# %%
# Now we mad a decision tree using Graphiz

# %%
joblib.dump(model,"name.joblib")
# Out:
# ['name.joblib']

# %%
sklearn.tree.export_graphviz(model,
                     out_file ="iris.dot",
                     feature_names=['sepal_length','sepal_width','petal_length','petal_width'],
                     class_names =sorted(y.unique()),
                     label = 'all',
                     rounded= True,
                     filled=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [104], line 1
# ----> 1 sklearn.tree.export_graphviz(model,
#       2                      out_file ="iris.dot",
#       3                      feature_names=['sepal_length','sepal_width','petal_length','petal_width'],
#       4                      class_names =sorted(y.unique()),
#       5                      label = 'all',
#       6                      rounded= True,
#       7                      filled=True)
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\tree\_export.py:888, in export_graphviz(decision_tree, out_file, max_depth, feature_names, class_names, label, filled, leaves_parallel, impurity, node_ids, proportion, rotate, rounded, special_characters, precision, fontname)
#     869     out_file = StringIO()
#     871 exporter = _DOTTreeExporter(
#     872     out_file=out_file,
#     873     max_depth=max_depth,
#    (...)
#     886     fontname=fontname,
#     887 )
# --> 888 exporter.export(decision_tree)
#     890 if return_string:
#     891     return exporter.out_file.getvalue()
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\tree\_export.py:451, in _DOTTreeExporter.export(self, decision_tree)
#     449 if self.feature_names is not None:
#     450     if len(self.feature_names) != decision_tree.n_features_in_:
# --> 451         raise ValueError(
#     452             "Length of feature_names, %d does not match number of features, %d"
#     453             % (len(self.feature_names), decision_tree.n_features_in_)
#     454         )
#     455 # each part writes to out_file
#     456 self.head()
#
# ValueError: Length of feature_names, 4 does not match number of features, 6

# %% [markdown]
# # Decison tree using Ttitanic data set

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
# use only that have not null values 
X = titanic[['survived','pclass','parch','sibsp']]
y = titanic['sex']

# %%
X.isnull().sum()
# Out:
# survived    0
# pclass      0
# parch       0
# sibsp       0
# dtype: int64

# %%
X.head()
# Out:
#    survived  pclass  parch  sibsp
# 0         0       3      0      1
# 1         1       1      0      1
# 2         1       3      0      0
# 3         1       1      0      1
# 4         0       3      0      0

# %%
y.head()
# Out:
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# Name: sex, dtype: object

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %%
model.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
model.predict([[0,3,0,1]])
# Out:
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['male'], dtype=object)

# %%
model.predict([[1,1,0,1]])
# Out:
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['female'], dtype=object)

# %%
model.score(X,y)
# Out:
# 0.8092031425364759

# %%
plt.plot(X,y)
# Out:
# [<matplotlib.lines.Line2D at 0x20eaa1cf010>,
#  <matplotlib.lines.Line2D at 0x20eaa1cf670>,
#  <matplotlib.lines.Line2D at 0x20eaa1cd450>,
#  <matplotlib.lines.Line2D at 0x20eaa1cefb0>]

# %% [markdown]
# # now Using splitting data    Train test split

# %%
# now Using splitting data

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.20,random_state=0)

# %%
X_train.head()
# Out:
#      survived  pclass  parch  sibsp
# 696         0       3      0      0
# 621         1       1      0      1
# 461         0       3      0      0
# 598         0       3      0      0
# 139         0       1      0      0

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# model.predict(X_test)

# %%
model.predict([[0,3,0,0]])
# Out:
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['male'], dtype=object)

# %%
model.predict([[1,3,0,0]])
# Out:
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['female'], dtype=object)

# %%
model.score(X_test,y_test)
# Out:
# 0.7377279102384292

# %%
sklearn.tree.export_graphviz(model,
                            out_file = "titanic.dot",
                            feature_names=['survived','pclass','parch','sibsp'],
                            class_names= sorted(y.unique()),
                            label='all',
                            rounded ='True',
                            filled ='True')

# %% [markdown]
# # Decision tree data save file in pdf,tiff, or png

# %%
dff = sns.load_dataset("mpg")
dff.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
dff.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
dff['horsepower'] = dff['horsepower'].fillna(dff['horsepower'].mean())

# %%
dff.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
X = dff[['mpg','cylinders','displacement','horsepower','weight','acceleration']]
y = dff['name']

# %%
X.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5

# %%
y.head()
# Out:
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# 2           plymouth satellite
# 3                amc rebel sst
# 4                  ford torino
# Name: name, dtype: object

# %%
y.sample(5)
# Out:
# 38     chevrolet impala
# 243          mazda rx-4
# 246    mazda glc deluxe
# 276          saab 99gle
# 256     plymouth volare
# Name: name, dtype: object

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
model.predict([[18.0,8,307.0,104.469388,3504,12.0]])
# Out:
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['oldsmobile cutlass ls'], dtype=object)

# %%
model.predict([[17.0,8,302.0,104.469388,3449,10.5]])
# Out:
# c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['amc concord d/l'], dtype=object)

# %%
# from sklearn.metrics import accuracy_score
# accuracy_score(X,y)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=0)
model = DecisionTreeClassifier()
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
yp=model.predict(X_test)

# %%
model.score(X_test,y_test)
# Out:
# 0.025

# %%
sklearn.tree.export_graphviz(model,
                             out_file="gppm.dot",
                             feature_names = ['mpg','cylinders','displacement','horsepower','weight','acceleration'],
                             class_names=sorted(y.unique()),
                             label="all",
                             rounded = True,
                             filled =True)

# %% [markdown]
# # How to save the Decision Tree

# %%
# from sklearn.tree import plot_tree
# plot_tree(model,filled=True)
# plt.savefig("tiff_compresssed.tiff",dpi =600,format = 'tiff',
#             facecolor = 'white',edgecolor = None)
# pil_kwargs = {"compression":"tiff_lzw"}
# plt.show()
